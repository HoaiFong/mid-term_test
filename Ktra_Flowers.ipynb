# %%
###

# %%
# %cd /content/drive/MyDrive/Kiemtra/5_kinds_of_flowers
# Out:
# /content/drive/MyDrive/Kiemtra/5_kinds_of_flowers

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range =0.2, horizontal_flip = True)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Kiemtra/5_kinds_of_flowers/Train', target_size = (150,150), batch_size = 32, class_mode ='categorical')
# Out:
# Found 2448 images belonging to 5 classes.

# %%
training_set.class_indices
# Out:
# {'apricot flower': 0, 'daisy pink': 1, 'lotus': 2, 'rose': 3, 'water lily': 4}

# %%
#mô hình CNN
from keras import models
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Normalization, Dropout
from keras.layers import LeakyReLU

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()

# Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
#ham loai bo
model.add(LeakyReLU(alpha = 0.1))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))

# Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
#ham loai bo
model.add(LeakyReLU(alpha = 0.1))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))

# Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
#ham loai bo
model.add(LeakyReLU(alpha = 0.1))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))


# Duỗi thẳng dữ liệu 
model.add(Flatten())

# Tạo lớp thứ nhất với 256 tín hiệu ra
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(LeakyReLU(alpha = 0.1))
# Tạo lớp thứ hai với 3 tín hiệu ra
model.add(Dense(5,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_9 (Conv2D)           (None, 150, 150, 32)      896
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 150, 150, 32)      0
#
#  max_pooling2d_9 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 75, 75, 64)        18496
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 75, 75, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 37, 37, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 128)       73856
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 37, 37, 128)       0
#
#  max_pooling2d_11 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 41472)             0
#
#  dense_6 (Dense)             (None, 256)               10617088
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 256)               0
#
#  dense_7 (Dense)             (None, 5)                 1285
#
# ...

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import to_categorical # one hot encoding cho output

# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 50 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size)
history=model.fit(training_set,epochs=30,batch_size=64,verbose=1)
# Out:
# Epoch 1/30
# 60/77 [======================>.......] - ETA: 34s - loss: 2.5243 - accuracy: 0.5888
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-af5a99471e1e> in <cell line: 7>()
#       5 model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
#       6 # Gán biến lại để vẽ đồ thị, với 50 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size)
# ----> 7 history=model.fit(training_set,epochs=30,batch_size=64,verbose=1)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
